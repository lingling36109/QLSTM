# %%
import qiskit
import pennylane as qml
import qiskit.providers.aer.noise as noise

# create a bit flip error with probability p = 0.01
p = 0.01
my_bitflip = noise.pauli_error([('X', p), ('I', 1 - p)])

# create an empty noise model
my_noise_model = noise.NoiseModel()

# attach the error to the hadamard gate 'h'
my_noise_model.add_quantum_error(my_bitflip, ['h'], [0])

dev4 = qml.device('qiskit.aer', wires=1, noise_model = my_noise_model)
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 # attach the error to the hadamard gate 'h'
#      13 my_noise_model.add_quantum_error(my_bitflip, ['h'], [0])
# ---> 15 dev4 = qml.device('qiskit.aer', wires=1, noise_model = my_noise_model)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pennylane/__init__.py:328, in device(name, *args, **kwargs)
#     325 options.update(kwargs)
#     327 # loads the device class
# --> 328 plugin_device_class = plugin_devices[name].load()
#     330 if Version(version()) not in SimpleSpec(plugin_device_class.pennylane_requires):
#     331     raise DeviceError(
#     332         f"The {name} plugin requires PennyLane versions {plugin_device_class.pennylane_requires}, "
#     333         f"however PennyLane version {__version__} is installed."
#     334     )
#
# File /opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:2516, in EntryPoint.load(self, require, *args, **kwargs)
#    2509     warnings.warn(
#    2510         "Parameters to load are deprecated.  Call .resolve and "
#    2511         ".require separately.",
#    2512         PkgResourcesDeprecationWarning,
#    2513         stacklevel=2,
#    2514     )
#    2515 if require:
# -> 2516     self.require(*args, **kwargs)
#    2517 return self.resolve()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:2539, in EntryPoint.require(self, env, installer)
#    2533 # Get the requirements for this entry point with all its extras and
#    2534 # then resolve them. We have to pass `extras` along when resolving so
#    2535 # that the working set knows what extras we want. Otherwise, for
#    2536 # dist-info distributions, the working set will assume that the
#    2537 # requirements for that extra are purely optional and skip over them.
#    2538 reqs = self.dist.requires(self.extras)
# -> 2539 items = working_set.resolve(reqs, env, installer, extras=self.extras)
#    2540 list(map(working_set.add, items))
#
# File /opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:827, in WorkingSet.resolve(self, requirements, env, installer, replace_conflicting, extras)
#     824 if not req_extras.markers_pass(req, extras):
#     825     continue
# --> 827 dist = self._resolve_dist(
#     828     req, best, replace_conflicting, env, installer, required_by, to_activate
#     829 )
#     831 # push the new requirements onto the stack
#     832 new_requirements = dist.requires(req.extras)[::-1]
#
# File /opt/anaconda3/lib/python3.9/site-packages/pkg_resources/__init__.py:873, in WorkingSet._resolve_dist(self, req, best, replace_conflicting, env, installer, required_by, to_activate)
#     870 if dist not in req:
#     871     # Oops, the "best" so far conflicts with a dependency
#     872     dependent_req = required_by[req]
# --> 873     raise VersionConflict(dist, req).with_context(dependent_req)
#     874 return dist
#
# ContextualVersionConflict: (websocket-client 0.58.0 (/opt/anaconda3/lib/python3.9/site-packages), Requirement.parse('websocket-client>=1.5.1'), {'qiskit-ibm-provider', 'qiskit-ibm-runtime', 'qiskit-ibmq-provider'})

# %%
pip list
# Out:
# WARNING: Ignoring invalid distribution -cipy (/opt/anaconda3/lib/python3.9/site-packages)
# Package                            Version
# ---------------------------------- --------------
# absl-py                            1.3.0
# aiohttp                            3.8.3
# aiosignal                          1.2.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.4.0
# anaconda-project                   0.10.1
# antlr4-python3-runtime             4.9.2
# anyio                              3.5.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        21.3.0
# argon2-cffi-bindings               21.2.0
# arrow                              1.2.3
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            5.1
# asttokens                          2.0.5
# astunparse                         1.6.3
# async-generator                    1.10
# async-timeout                      4.0.2
# atomicwrites                       1.4.0
# attrs                              22.1.0
# autograd                           1.4
# Automat                            20.2.0
# autopep8                           1.6.0
# autoray                            0.3.2
# Babel                              2.11.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.12.2
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              0.0
# bleach                             4.1.0
# blinker                            1.4
# bokeh                              2.4.3
# boltons                            23.0.0
# boto                               2.49.0
# boto3                              1.24.28
# botocore                           1.27.59
# Bottleneck                         1.3.5
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         5.0.0
# certifi                            2023.5.7
# cffi                               1.15.1
# chardet                            4.0.0
# charset-normalizer                 3.1.0
# click                              8.0.4
# cloudpickle                        2.2.1
# clyent                             1.2.2
# colorama                           0.4.6
# colorcet                           3.0.1
# comm                               0.1.2
# conda                              23.3.1
# conda-build                        3.25.0
# conda-content-trust                0.1.3
# conda_index                        0.2.3
# conda-pack                         0.6.0
# conda-package-handling             2.1.0
# conda_package_streaming            0.8.0
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# constantly                         15.1.0
# contextlib2                        0.6.0.post1
# contourpy                          1.0.5
# cookiecutter                       1.7.2
# cryptography                       41.0.1
# cssselect                          1.1.0
# cycler                             0.11.0
# Cython                             0.29.35
# cytoolz                            0.12.0
# daal4py                            2023.1.1
# dask                               2023.4.1
# datashader                         0.14.4
# datashape                          0.5.4
# debugpy                            1.5.1
# decorator                          5.1.1
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# dill                               0.3.6
# distributed                        2023.4.1
# docutils                           0.17.1
# entrypoints                        0.4
# et-xmlfile                         1.1.0
# exceptiongroup                     1.0.4
# executing                          0.8.3
# fastcache                          1.1.0
# fastjsonschema                     2.16.2
# filelock                           3.9.0
# fire                               0.5.0
# flake8                             3.9.2
# Flask                              1.1.2
# flatbuffers                        2.0
# fonttools                          4.25.0
# frozenlist                         1.3.3
# fsspec                             2023.4.0
# future                             0.18.3
# gast                               0.4.0
# gensim                             4.3.0
# gevent                             22.10.2
# glob2                              0.7
# gmpy2                              2.1.2
# google-auth                        2.6.0
# google-auth-oauthlib               0.4.4
# google-pasta                       0.2.0
# greenlet                           2.0.1
# grpcio                             1.42.0
# h5py                               3.7.0
# HeapDict                           1.0.1
# holoviews                          1.16.0
# html5lib                           1.1
# huggingface-hub                    0.14.1
# hvplot                             0.8.3
# hyperlink                          21.0.0
# ibm-cloud-sdk-core                 3.16.7
# ibm-platform-services              0.37.0
# idna                               3.4
# imagecodecs                        2021.8.26
# imageio                            2.26.0
# imagesize                          1.4.1
# imbalanced-learn                   0.10.1
# importlib-metadata                 6.0.0
# importlib-resources                5.2.0
# incremental                        21.3.0
# inflection                         0.5.1
# iniconfig                          1.1.1
# intake                             0.6.8
# intervaltree                       3.1.0
# ipykernel                          6.19.2
# ipython                            8.12.0
# ipython-genutils                   0.2.0
# ipywidgets                         8.0.4
# isort                              5.9.3
# itemadapter                        0.3.0
# itemloaders                        1.0.4
# itsdangerous                       2.0.1
# jaraco.classes                     3.2.1
# jdcal                              1.4.1
# jedi                               0.18.1
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# jmespath                           0.10.0
# joblib                             1.2.0
# json5                              0.9.6
# jsonpatch                          1.32
# jsonpointer                        2.1
# jsonschema                         4.17.3
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter_core                       5.3.0
# jupyter-server                     1.13.5
# jupyterlab                         3.2.1
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.8.2
# jupyterlab-widgets                 3.0.5
# keras                              2.10.0
# Keras-Preprocessing                1.1.2
# keyring                            23.13.1
# kiwisolver                         1.4.4
# lark-parser                        0.12.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# llvmlite                           0.40.0
# lmdb                               1.4.1
# locket                             1.0.0
# lxml                               4.9.2
# Markdown                           3.4.1
# MarkupSafe                         1.1.1
# matplotlib                         3.7.1
# matplotlib-inline                  0.1.6
# mccabe                             0.6.1
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.12.0
# mpmath                             1.3.0
# msgpack                            1.0.3
# mthree                             2.5.1
# multidict                          6.0.2
# multipledispatch                   0.6.0
# munkres                            1.1.4
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.5.5
# nbclient                           0.5.13
# nbconvert                          6.1.0
# nbformat                           5.7.0
# nest-asyncio                       1.5.6
# networkx                           3.1
# nltk                               3.7
# nose                               1.3.7
# notebook                           6.5.4
# notebook_shim                      0.2.2
# ntlm-auth                          1.5.0
# numba                              0.57.0
# numexpr                            2.8.4
# numpy                              1.23.0
# numpydoc                           1.1.0
# oauthlib                           3.2.2
# olefile                            0.46
# opencv-python                      4.7.0.72
# openpyxl                           3.0.10
# opt-einsum                         3.3.0
# orjson                             3.9.1
# packaging                          23.0
# pandas                             1.3.4
# pandocfilters                      1.5.0
# panel                              0.14.3
# param                              1.13.0
# parsel                             1.6.0
# parso                              0.8.3
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.10.3
# patsy                              0.5.3
# pbr                                5.11.1
# PennyLane                          0.31.0
# PennyLane-Lightning                0.31.0
# PennyLane-qiskit                   0.31.0
# pennylane-qulacs                   0.29.0
# PennyLane-SF                       0.29.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             9.4.0
# pip                                23.0.1
# pkginfo                            1.9.6
# platformdirs                       2.5.2
# plotly                             5.9.0
# pluggy                             1.0.0
# ply                                3.11
# pooch                              1.4.0
# poyo                               0.5.0
# prometheus-client                  0.14.1
# prompt-toolkit                     3.0.36
# Protego                            0.1.16
# protobuf                           3.20.3
# psutil                             5.9.5
# ptyprocess                         0.7.0
# pure-eval                          0.2.2
# py                                 1.10.0
# py-cpuinfo                         8.0.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycodestyle                        2.7.0
# pycosat                            0.6.4
# pycparser                          2.21
# pyct                               0.5.0
# pycurl                             7.45.2
# pydantic                           1.10.9
# PyDispatcher                       2.0.5
# pydocstyle                         6.3.0
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.15.1
# PyJWT                              2.7.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# pyodbc                             4.0.34
# pyOpenSSL                          23.0.0
# pyparsing                          3.0.9
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pyspnego                           0.9.1
# pytest                             7.3.1
# python-dateutil                    2.8.2
# python-dotenv                      1.0.0
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# python-snappy                      0.6.1
# pytoolconfig                       1.2.5
# pytz                               2022.7
# pyviz-comms                        2.3.0
# PyWavelets                         1.4.1
# PyYAML                             6.0
# pyzmq                              25.0.2
# QDarkStyle                         3.0.2
# qiskit                             0.42.1
# qiskit-aer                         0.12.0
# qiskit-ibm-provider                0.6.0
# qiskit-ibm-runtime                 0.9.3
# qiskit-ibmq-provider               0.20.2
# qiskit-ignis                       0.7.1
# qiskit-terra                       0.24.1
# qiskit-textbook                    0.1.0
# qstylizer                          0.2.2
# QtAwesome                          1.2.2
# qtconsole                          5.4.2
# QtPy                               2.2.0
# quantum-blackbird                  0.5.0
# quantum-xir                        0.2.2
# queuelib                           1.5.0
# qulacs                             0.6.1
# regex                              2022.7.9
# requests                           2.31.0
# requests-file                      1.5.1
# requests-ntlm                      1.2.0
# requests-oauthlib                  1.3.0
# retworkx                           0.13.0
# rope                               1.7.0
# rsa                                4.7.2
# Rtree                              1.0.1
# ruamel.yaml                        0.17.21
# ruamel.yaml.clib                   0.2.6
# ruamel-yaml-conda                  0.15.100
# rustworkx                          0.13.0
# s3transfer                         0.6.0
# scikit-image                       0.19.3
# scikit-learn                       1.2.2
# scikit-learn-intelex               20230426.61523
# scipy                              1.10.0
# Scrapy                             2.8.0
# seaborn                            0.12.2
# semantic-version                   2.10.0
# Send2Trash                         1.8.0
# service-identity                   18.1.0
# setuptools                         67.8.0
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# smart-open                         5.2.1
# sniffio                            1.2.0
# snowballstemmer                    2.2.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.4
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.39
# stack-data                         0.2.0
# statsmodels                        0.13.5
# stevedore                          5.1.0
# StrawberryFields                   0.23.0
# symengine                          0.9.2
# sympy                              1.12
# tables                             3.8.0
# tabulate                           0.8.10
# TBB                                0.2
# tblib                              1.7.0
# tenacity                           8.2.2
# tensorboard                        2.10.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.6.0
# tensorflow                         2.10.0
# tensorflow-estimator               2.10.0
# termcolor                          2.1.0
# terminado                          0.17.1
# testpath                           0.6.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# thewalrus                          0.20.0
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# tinycss2                           1.2.1
# tldextract                         3.2.0
# tokenizers                         0.11.4
# toml                               0.10.2
# tomli                              2.0.1
# toolz                              0.12.0
# torch                              1.13.1
# tornado                            6.2
# tqdm                               4.65.0
# traitlets                          5.7.1
# transformers                       4.24.0
# Twisted                            22.10.0
# typed-ast                          1.4.3
# typing_extensions                  4.6.3
# ujson                              5.4.0
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# urllib3                            2.0.3
# utils                              1.0.1
# w3lib                              1.21.0
# watchdog                           2.1.6
# wavelet-buffer                     0.6.0
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.5.2
# websockets                         11.0.3
# Werkzeug                           2.0.3
# wheel                              0.35.1
# whichcraft                         0.6.1
# widgetsnbextension                 4.0.5
# wrapt                              1.12.1
# wurlitzer                          3.0.2
# xanadu-cloud-client                0.3.0
# xarray                             2022.11.0
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.29.1
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# yarl                               1.8.1
# zict                               2.2.0
# zipp                               3.11.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# zstandard                          0.19.0
# WARNING: Ignoring invalid distribution -cipy (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/anaconda3/lib/python3.9/site-packages)
# WARNING: Ignoring invalid distribution -cipy (/opt/anaconda3/lib/python3.9/site-packages)
# Note: you may need to restart the kernel to use updated packages.

# %%
python3-m pip install  websocket-client==1.5.2
# Out:
#   Cell In[11], line 1
#     python3 pip install  websocket-client==1.5.2
#             ^
# SyntaxError: invalid syntax
